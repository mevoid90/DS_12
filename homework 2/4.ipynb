# %%
str=input('Введите 2 слова')
n=str.split(" ")
res1=n[0]
res2=n[1]
reserved_str1=res1[::-1]
reserved_str2=res2[::-1]
# Out:
# Введите 2 слова asdasd fswerw

# %%
print(reserved_str1)
print(reserved_str2)
# Out:
# dsadsa
# wrewsf
